# %% [markdown]
# <!-- Optimizers -->

# %% [markdown]
# # Optimizers

# %%
# In ML we have 3 optimizers :
# Gradient Descent --- > all data trained --- > prediction will close to actual point .
# Stocastic G.D. ---- > 100 rows --- > 1 random row --- > y = mx + b
# Mini Batch G.D. ---- > 100 rows --- > 4 batches (A=25,B=25,C=25,D=25) --- > random batch (B=25) --- > y = mx + b
# In DL --- >
# Stocastic G.D. (Issue local minima stuck) -- > solve momentum(0.9) , previous squared gradients claculation ---- > NAG(solve
# issue of stucking in local minima and it calculates future squared gradients as well as past squared gradients) --- >
# AdaGrad(Provide Automatic Learning rate) -- > solve RMSProp(Provide solution of automatic Ir) --- >
# Adam(combination of 2 optimizers a. Momentum b. RMSprop)

# %%
# # Backpropagration And Forward propagation
# D
# Age(x11)
#                     .x21
# BMI(x12)                  .x31  --------> Output charges(y)                               
# #output layer
#                    .x22
# children(x13)   ------> ##hidden layer
    # input layer

# %%
# Forward Propagation ------------->
# step-1
# x11--- > x21 --- > x31 --- > y
# x11 ---- > x22 --- > x31 --- > y

# step-2
# x12---->  x21-- > x31 -- > y 
# x12 --->  x22-- > x31 -- > y 

# step-3
# x13---->  x21-- > x31 -- > y 
# x13 --->  x22-- > x31 -- > y

# %%
# Back Propagation
# step-1
# dy/dx11 = dy/dx31* dx31/dx21* dx21/dx11
# dy/dx11 = dy/dx31* dx31/dx22* dx22/dx11
I

# step-2 |
# dy/dx12 = dy/dx31* dx31/dx21* dx21/dx12
# dy/dx12 = dy/dx31* dx31/dx22* dx22/dx12

# step-3
# dy/dx13 = dy/dx31* dx31/dx21* dx21/dx13
# dy/dx13 = dy/dx31* dx31/dx22* dx22/dx13

# y = mx + b
